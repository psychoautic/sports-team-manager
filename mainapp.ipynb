# %%
from models.models import Player, Team, Match


team1 = Team("Red Warriors")
team2 = Team("Blue Hawks")

players1 = [Player(f"RW_Player{i}", "ST", i) for i in range(1, 12)]
players2 = [Player(f"BH_Player{i}", "CB", i+11) for i in range(1, 12)]

for p in players1:
    team1.add_player(p)
for p in players2:
    team2.add_player(p)

team1.select_lineup(players1[:11])
team2.select_lineup(players2[:11])

match = Match(team1, team2, date="2025-05-28", stadium="National Stadium")
match.match_simulate()
# Out:
# Match between Red Warriors and Blue Hawks has started at National Stadium on 2025-05-28
# Match ended with score: Red Warriors 2 - 2 Blue Hawks
# Result: Draw
#
# 📊 Player Stats This Match:
# RW_Player1: 0 goals, 0 assists
# RW_Player2: 0 goals, 0 assists
# RW_Player3: 0 goals, 0 assists
# RW_Player4: 0 goals, 0 assists
# RW_Player5: 0 goals, 0 assists
# RW_Player6: 1 goals, 0 assists
# RW_Player7: 1 goals, 0 assists
# RW_Player8: 0 goals, 1 assists
# RW_Player9: 0 goals, 0 assists
# RW_Player10: 0 goals, 1 assists
# RW_Player11: 0 goals, 0 assists
# BH_Player1: 0 goals, 0 assists
# BH_Player2: 1 goals, 0 assists
# BH_Player3: 0 goals, 1 assists
# BH_Player4: 0 goals, 0 assists
# BH_Player5: 1 goals, 0 assists
# BH_Player6: 0 goals, 0 assists
# BH_Player7: 0 goals, 0 assists
# BH_Player8: 0 goals, 0 assists
# BH_Player9: 0 goals, 1 assists
# BH_Player10: 0 goals, 0 assists
# BH_Player11: 0 goals, 0 assists

# %%
team1.add_player(Player("RW_Player12", "GK", 12))

# %%
team1.team_info()

team1.remove_player()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 team1.team_info()
# ----> 3 team1.remove_player('RW_Player1')
#
# File c:\Users\raeda\Documents\github\sports-team-manager\models\models.py:84, in Team.remove_player(self, player)
#      82 def remove_player(self, player: 'Player'):
#      83     if not isinstance(player, Player):
# ---> 84         raise TypeError("Player must be an instance of Player class")
#      85     if player in self.players:
#      86         self.players.remove(player)
#
# TypeError: Player must be an instance of Player class
